# %%
import pandas as pd
from random import choice
from random import randrange

# %%
def loadHumanNeed():
    student = pd.read_excel('human/student.xlsx')
    employed = pd.read_excel('human/employed.xlsx')
    unemployed = pd.read_excel('human/unemployed.xlsx')
    healthcare = pd.read_excel('human/healthcare.xlsx')
    return employed, unemployed, student, healthcare

# %%
def Sort_Tuple(tup): 
      
    # getting length of list of tuples
    lst = len(tup) 
    for i in range(0, lst): 
          
        for j in range(0, lst-i-1): 
            if (tup[j][1] > tup[j + 1][1]): 
                temp = tup[j] 
                tup[j]= tup[j + 1] 
                tup[j + 1]= temp 
    return tup 

# to get tuple info. of maximum value tuple
# using max() + itemgetter()
from operator import itemgetter
  
def choosePlace(n, list_val):
    # declaring the list 
    # new_list is a set of list1  
    res_list = list_val 
    if n > 0:
        for i in range(0,n-1):
            res_list.remove(max(res_list, key = lambda i : i[1]))
    
    result = max(res_list, key = lambda i : i[1])
    return result

# %%
import random
from random import choice
import math
import time
def generateTasks():

    df = []
    employed, unemployed, student, healthcare = loadHumanNeed()
    agentType = ["Student", "Employed", "Unemployed", "Healthcare"]
    headers = ["task", "min_start_time" , "max_start_time" , "min_duration" , "max_duration" , "profession", "min_prob" , "max_prob" ]
    for p in agentType:
        profession = p
        if p == "Student":
            data = student
        if p == "Employed":
            data = employed
        if p == "Unemployed":
            data = unemployed
        if p == "Healthcare":
            data = healthcare

        
        firstRow = data.iloc[0]
        currentP = firstRow["start"]
   
        nextP = firstRow["start"]
        duration = 0
        currentTime = randrange(12)

        timeCount = 0
        row = firstRow
        prob = 0.5
        nextTask = ""
        while timeCount < 24:
            min_start_time = currentTime
            max_start_time = round (random.choice([currentTime,currentTime + 2*random.random()]))
            currentP = nextP
            if currentP == "home":
                taskName = "stay home"
                minProb = prob
                maxProb = random.random()
                if maxProb < minProb:
                    maxProb = minProb
                if prob > 0.4:
                    duration = 4 + round(4 * random.random())
                else:
                    duration = 1 + round(2 * random.random())
                maxduration = random.choice([duration, duration+1])
            
            elif currentP == "work":
                taskName = "work"
                minProb = prob
                maxProb = random.random()
                if maxProb < minProb:
                    maxProb = minProb
                if prob > 0.4:
                    duration = 4 + round(4 * random.random())
                else:
                    duration = 1 + round( random.random())
                maxduration = random.choice([duration, duration+1])
              
            elif currentP == "hospital":
                taskName = "treat patients"
                minProb = prob
                maxProb = random.random()
                if maxProb < minProb:
                    maxProb = minProb
                if prob > 0.4:
                    duration = 6 + round(2 * random.random())
                else:
                    duration = 2 + round(2 * random.random())
                maxduration = random.choice([duration, duration+1])
               
            elif currentP == "market":
                minProb = prob
                maxProb = random.random()
                if maxProb < minProb:
                    maxProb = minProb
                if prob > 0.4:
                    duration = 2 + round(2 * random.random())
                    taskName = random.choice([ "meeting","attending event","relaxation","dating"])
                else:
                    duration = 1 + round(random.random())
                    taskName = random.choice(["shopping", "eating"])
                maxduration = random.choice([duration, duration+1])
            
            elif currentP == "school":
                minProb = prob
                maxProb = random()
                if maxProb < minProb:
                    maxProb = minProb
                if prob > 0.4:
                    taskName = random.choice(["class time", "researching" ])
                    duration = 3 + round(5 * random.random())
                else:
                    taskName = random.choice(["groupwork", "homework" ])
                    duration = 2 + round(2 * random.random())
                maxduration = random.choice([duration, duration+1])
            

            #update currentTime and timeCount, adjust duration
            if (timeCount + duration) >= 22:
                duration = 24 - timeCount
            currentTime = currentTime + duration
            timeCount = timeCount + duration
      
            df.append([taskName, min_start_time, max_start_time, duration, maxduration, p, minProb, maxProb])
            if currentTime >= 24:
                currentTime -= 24 # set currentime if it is above 24 hour clock
              #if there is not enough time left, stay in the same place
            if timeCount > 23:
                continue
            #next activity  
            row = data.loc[data['start'] == currentP]
           # currentP = row["start"].value
            chooseList = []
            for place in ["home", "work", "hospital", "market", "school"]:
                if float(row[place]) > 0:
                    chooseList.append((place,float(row[place])))
            selectNumber = 0
            nextProb = prob
            while (nextP == currentP) and (nextProb == prob):
                #n1 = math.floor(random.random()* len(chooseList))
                #selectNumber = random.choice([0, n1])
                place = choosePlace(selectNumber, chooseList)
                nextP = place[0]
                nextProb = place[1]
                selectNumber += 1
            prob = nextProb
            if nextP == currentP:
                currentP = nextP
                continue
                
            if nextP == "home":
                nextTask = "go home"
            elif nextP == "work":
                nextTask = "go to work"
            elif nextP == "hospital":
                nextTask = "go to Hospital"
            elif nextP == "school":
                nextTask = "go to school"
            else:
                nextTask = "go to market"
            minProb = random.random()* prob
            maxProb = random.random()* prob
            if maxProb < minProb:
                maxProb = minProb
            duration = round (1 + random.random())
            min_start_time = currentTime
            max_start_time = round( random.choice([currentTime,currentTime + random.random()]))
            #update currentTime and timeCount, adjust duration
            if (timeCount + duration) >= 24:
                duration = 24 - timeCount
            currentTime = currentTime + duration
            timeCount = timeCount + duration
            df.append([nextTask, min_start_time, max_start_time, duration, duration, p, minProb, maxProb])

            if currentTime >= 24:
                currentTime -= 24 # set currentime if it is above 24 hour clock    
           # time.sleep(5)

    database = pd.DataFrame(df, columns=[headers])         

    return database

# %%
database = generateTasks()

# %%
database
# Out:
#                task min_start_time max_start_time min_duration max_duration  \
# 0         stay home              5              5            6            6
# 1         stay home             11             11            5            5
# 2      go to market             16             16            2            2
# 3   attending event             18             20            4            4
# 4           go home             22             22            1            1
# 5         stay home             23             23            6            6
# 6         stay home              8             10            5            6
# 7        go to work             13             13            1            1
# 8              work             14             14            6            7
# 9           go home             20             20            1            1
# 10        stay home             21             21            5            5
# 11       go to work              2              2            1            1
# 12             work              3              4            5            6
# 13        stay home              0              0            5            6
# 14        stay home              5              5            4            5
# 15     go to market              9             10            1            1
# 16       relaxation             10             11            2            2
# 17          go home             12             12            2            2
# 18        stay home             14             14            4            4
# 19        stay home             18             18            6            8
# 20        stay home             10             11            5            6
# 21   go to Hospital             15             16            2            2
# 22   treat patients             17             17            8            9
# 23          go home              1              1            1            1
# 24        stay home              2              2            8            7
#
#     profession  min_prob  max_prob
# 0      Student  0.500000  0.500000
# 1      Student  0.900000  0.900000
# 2      Student  0.571932  0.571932
# 3      Student  0.700000  0.767969
# 4      Student  0.061039  0.109657
# 5      Student  0.900000  0.900000
# 6     Employed  0.500000  0.671149
# 7     Employed  0.891015  0.891015
# 8     Employed  0.900000  0.900000
# 9     Employed  0.455600  0.455600
# 10    Employed  0.500000  0.941246
# 11    Employed  0.440930  0.790692
# 12    Employed  0.900000  0.928463
# 13  Unemployed  0.500000  0.500000
# 14  Unemployed  0.900000  0.900000
# 15  Unemployed  0.596406  0.596406
# 16  Unemployed  0.700000  0.700000
# 17  Unemployed  0.654542  0.654542
# 18  Unemployed  0.800000  0.800000
# 19  Unemployed  0.900000  0.900000
# 20  Healthcare  0.500000  0.971146
# 21  Healthcare  0.517062  0.517062
# 22  Healthcare  0.900000  0.900000
# 23  Healthcare  0.018238  0.204226
# 24  Healthcare  0.500000  0.986739

# %%
random.choice(["class time", "researching" ])
# Out:
# 'researching'

# %%
import random
from random import choice
import math
import time
def generateStudentTasks(n):

    df = []
    employed, unemployed, student, healthcare = loadHumanNeed()
    
    headers = [ "ID","task", "min_start_time" , "max_start_time" , "min_duration" , "max_duration" , "profession", "min_prob" , "max_prob" ]
    data = student
    for i in range(0, n):
        p = "Student"
        iD = "st" + str(i)
 
        firstRow = data.iloc[0]
        currentP = firstRow["start"]
   
        nextP = firstRow["start"]
        duration = 0
        currentTime = randrange(12)

        timeCount = 0
        row = firstRow

        prob = 0.5
        nextTask = ""
        while timeCount < 24:
            min_start_time = currentTime
            max_start_time = round (random.choice([currentTime,currentTime + 2*random.random()]))
            currentP = nextP
            if currentP == "home":
                taskName = "stay home"
                minProb = prob
                maxProb = random.random()
                if maxProb < minProb:
                    maxProb = minProb
                if prob > 0.4:
                    duration = 4 + round(4 * random.random())
                else:
                    duration = 1 + round(2 * random.random())
                maxduration = random.choice([duration, duration+1])
            
            elif currentP == "work":
                taskName = "work"
                minProb = prob
                maxProb = random.random()
                if maxProb < minProb:
                    maxProb = minProb
                if prob > 0.4:
                    duration = 4 + round(4 * random.random())
                else:
                    duration = 1 + round( random.random())
                maxduration = random.choice([duration, duration+1])
              
            elif currentP == "hospital":
                taskName = "treat patients"
                minProb = prob
                maxProb = random.random()
                if maxProb < minProb:
                    maxProb = minProb
                if prob > 0.4:
                    duration = 6 + round(2 * random.random())
                else:
                    duration = 2 + round(2 * random.random())
                maxduration = random.choice([duration, duration+1])
               
            elif currentP == "market":
                minProb = prob
                maxProb = random.random()
                if maxProb < minProb:
                    maxProb = minProb
                if prob > 0.4:
                    duration = 2 + round(2 * random.random())
                    taskName = random.choice([ "meeting","attending event","relaxation","dating"])
                else:
                    duration = 1 + round(random.random())
                    taskName = random.choice(["shopping", "eating"])
                maxduration = random.choice([duration, duration+1])
            
            elif currentP == "school":
                minProb = prob
                maxProb = rand()
                if maxProb < minProb:
                    maxProb = minProb
                if prob > 0.4:
                    taskName = random.choice(["class time", "researching" ])
                    duration = 3 + round(5 * random.random())
                else:
                    taskName = random.choice(["groupwork", "homework" ])
                    duration = 2 + round(2 * random.random())
                maxduration = random.choice([duration, duration+1])
            

            #update currentTime and timeCount, adjust duration
            if (timeCount + duration) >= 22:
                duration = 24 - timeCount
            currentTime = currentTime + duration
            timeCount = timeCount + duration
      
            df.append([iD, taskName, min_start_time, max_start_time, duration, maxduration, p, minProb, maxProb])
            if currentTime >= 24:
                currentTime -= 24 # set currentime if it is above 24 hour clock
              #if there is not enough time left, stay in the same place
            if timeCount > 23:
                continue
            #next activity  
            row = data.loc[data['start'] == currentP]
           # currentP = row["start"].value
            chooseList = []
            for place in ["home", "work", "hospital", "market", "school"]:
                if float(row[place]) > 0:
                    chooseList.append((place,float(row[place])))
            selectNumber = 0
            nextProb = prob
            while (nextP == currentP) and (nextProb == prob):
                #n1 = math.floor(random.random()* len(chooseList))
                #selectNumber = random.choice([0, n1])
                place = choosePlace(selectNumber, chooseList)
                nextP = place[0]
                nextProb = place[1]
                selectNumber += 1
            prob = nextProb
            if nextP == currentP:
                currentP = nextP
                continue
                
            if nextP == "home":
                nextTask = "go home"
            elif nextP == "work":
                nextTask = "go to work"
            elif nextP == "hospital":
                nextTask = "go to Hospital"
            elif nextP == "school":
                nextTask = "go to school"
            else:
                nextTask = "go to market"
            minProb = random.random()* prob
            maxProb = random.random()* prob
            if maxProb < minProb:
                maxProb = minProb
            duration = round (1 + random.random())
            min_start_time = currentTime
            max_start_time = round( random.choice([currentTime,currentTime + random.random()]))
            #update currentTime and timeCount, adjust duration
            if (timeCount + duration) >= 24:
                duration = 24 - timeCount
            currentTime = currentTime + duration
            timeCount = timeCount + duration
            df.append([ iD, nextTask, min_start_time, max_start_time, duration, duration, p, minProb, maxProb])

            if currentTime >= 24:
                currentTime -= 24 # set currentime if it is above 24 hour clock              

    database = pd.DataFrame(df, columns=[headers])         

    return database

# %%
import random
from random import choice
import math
import time
def generateEmployedTasks(n):

    df = []
    employed, unemployed, student, healthcare = loadHumanNeed()
    
    headers = [ "ID","task", "min_start_time" , "max_start_time" , "min_duration" , "max_duration" , "profession", "min_prob" , "max_prob" ]
    data = employed
    for i in range(0, n):
        p = "Employed"
        iD = "em" + str(i)
 
        firstRow = data.iloc[0]
        currentP = firstRow["start"]
   
        nextP = firstRow["start"]
        duration = 0
        currentTime = randrange(12)

        timeCount = 0
        row = firstRow

        prob = 0.5
        nextTask = ""
        while timeCount < 24:
            min_start_time = currentTime
            max_start_time = round (random.choice([currentTime,currentTime + 2*random.random()]))
            currentP = nextP
            if currentP == "home":
                taskName = "stay home"
                minProb = prob
                maxProb = random.random()
                if maxProb < minProb:
                    maxProb = minProb
                if prob > 0.4:
                    duration = 4 + round(4 * random.random())
                else:
                    duration = 1 + round(2 * random.random())
                maxduration = random.choice([duration, duration+1])
            
            elif currentP == "work":
                taskName = "work"
                minProb = prob
                maxProb = random.random()
                if maxProb < minProb:
                    maxProb = minProb
                if prob > 0.4:
                    duration = 4 + round(4 * random.random())
                else:
                    duration = 1 + round( random.random())
                maxduration = random.choice([duration, duration+1])
              
            elif currentP == "hospital":
                taskName = "treat patients"
                minProb = prob
                maxProb = random.random()
                if maxProb < minProb:
                    maxProb = minProb
                if prob > 0.4:
                    duration = 6 + round(2 * random.random())
                else:
                    duration = 2 + round(2 * random.random())
                maxduration = random.choice([duration, duration+1])
               
            elif currentP == "market":
                minProb = prob
                maxProb = random.random()
                if maxProb < minProb:
                    maxProb = minProb
                if prob > 0.4:
                    duration = 2 + round(2 * random.random())
                    taskName = random.choice([ "meeting","attending event","relaxation","dating"])
                else:
                    duration = 1 + round(random.random())
                    taskName = random.choice(["shopping", "eating"])
                maxduration = random.choice([duration, duration+1])
            
            elif currentP == "school":
                minProb = prob
                maxProb = rand()
                if maxProb < minProb:
                    maxProb = minProb
                if prob > 0.4:
                    taskName = random.choice(["class time", "researching" ])
                    duration = 3 + round(5 * random.random())
                else:
                    taskName = random.choice(["groupwork", "homework" ])
                    duration = 2 + round(2 * random.random())
                maxduration = random.choice([duration, duration+1])
            

            #update currentTime and timeCount, adjust duration
            if (timeCount + duration) >= 22:
                duration = 24 - timeCount
            currentTime = currentTime + duration
            timeCount = timeCount + duration
      
            df.append([iD, taskName, min_start_time, max_start_time, duration, maxduration, p, minProb, maxProb])
            if currentTime >= 24:
                currentTime -= 24 # set currentime if it is above 24 hour clock
              #if there is not enough time left, stay in the same place
            if timeCount > 23:
                continue
            #next activity  
            row = data.loc[data['start'] == currentP]
           # currentP = row["start"].value
            chooseList = []
            for place in ["home", "work", "hospital", "market", "school"]:
                if float(row[place]) > 0:
                    chooseList.append((place,float(row[place])))
            selectNumber = 0
            nextProb = prob
            while (nextP == currentP) and (nextProb == prob):
                #n1 = math.floor(random.random()* len(chooseList))
                #selectNumber = random.choice([0, n1])
                place = choosePlace(selectNumber, chooseList)
                nextP = place[0]
                nextProb = place[1]
                selectNumber += 1
            prob = nextProb
            if nextP == currentP:
                currentP = nextP
                continue
                
            if nextP == "home":
                nextTask = "go home"
            elif nextP == "work":
                nextTask = "go to work"
            elif nextP == "hospital":
                nextTask = "go to Hospital"
            elif nextP == "school":
                nextTask = "go to school"
            else:
                nextTask = "go to market"
            minProb = random.random()* prob
            maxProb = random.random()* prob
            if maxProb < minProb:
                maxProb = minProb
            duration = round (1 + random.random())
            min_start_time = currentTime
            max_start_time = round( random.choice([currentTime,currentTime + random.random()]))
            #update currentTime and timeCount, adjust duration
            if (timeCount + duration) >= 24:
                duration = 24 - timeCount
            currentTime = currentTime + duration
            timeCount = timeCount + duration
            df.append([ iD, nextTask, min_start_time, max_start_time, duration, duration, p, minProb, maxProb])

            if currentTime >= 24:
                currentTime -= 24 # set currentime if it is above 24 hour clock              

    database = pd.DataFrame(df, columns=[headers])         

    return database

# %%
import random
from random import choice
import math
import time
def generateUnemployedTasks(n):

    df = []
    employed, unemployed, student, healthcare = loadHumanNeed()
    
    headers = [ "ID","task", "min_start_time" , "max_start_time" , "min_duration" , "max_duration" , "profession", "min_prob" , "max_prob" ]
    data = unemployed
    for i in range(0, n):
        p = "Unemployed"
        iD = "un" + str(i)
 
        firstRow = data.iloc[0]
        currentP = firstRow["start"]
   
        nextP = firstRow["start"]
        duration = 0
        currentTime = randrange(12)

        timeCount = 0
        row = firstRow

        prob = 0.5
        nextTask = ""
        while timeCount < 24:
            min_start_time = currentTime
            max_start_time = round (random.choice([currentTime,currentTime + 2*random.random()]))
            currentP = nextP
            if currentP == "home":
                taskName = "stay home"
                minProb = prob
                maxProb = random.random()
                if maxProb < minProb:
                    maxProb = minProb
                if prob > 0.4:
                    duration = 4 + round(4 * random.random())
                else:
                    duration = 1 + round(2 * random.random())
                maxduration = random.choice([duration, duration+1])
            
            elif currentP == "work":
                taskName = "work"
                minProb = prob
                maxProb = random.random()
                if maxProb < minProb:
                    maxProb = minProb
                if prob > 0.4:
                    duration = 4 + round(4 * random.random())
                else:
                    duration = 1 + round( random.random())
                maxduration = random.choice([duration, duration+1])
              
            elif currentP == "hospital":
                taskName = "treat patients"
                minProb = prob
                maxProb = random.random()
                if maxProb < minProb:
                    maxProb = minProb
                if prob > 0.4:
                    duration = 6 + round(2 * random.random())
                else:
                    duration = 2 + round(2 * random.random())
                maxduration = random.choice([duration, duration+1])
               
            elif currentP == "market":
                minProb = prob
                maxProb = random.random()
                if maxProb < minProb:
                    maxProb = minProb
                if prob > 0.4:
                    duration = 2 + round(2 * random.random())
                    taskName = random.choice([ "meeting","attending event","relaxation","dating"])
                else:
                    duration = 1 + round(random.random())
                    taskName = random.choice(["shopping", "eating"])
                maxduration = random.choice([duration, duration+1])
            
            elif currentP == "school":
                minProb = prob
                maxProb = random.random()
                if maxProb < minProb:
                    maxProb = minProb
                if prob > 0.4:
                    taskName = random.choice(["class time", "researching" ])
                    duration = 3 + round(5 * random.random())
                else:
                    taskName = random.choice(["groupwork", "homework" ])
                    duration = 2 + round(2 * random.random())
                maxduration = random.choice([duration, duration+1])
            

            #update currentTime and timeCount, adjust duration
            if (timeCount + duration) >= 22:
                duration = 24 - timeCount
            currentTime = currentTime + duration
            timeCount = timeCount + duration
      
            df.append([iD, taskName, min_start_time, max_start_time, duration, maxduration, p, minProb, maxProb])
            if currentTime >= 24:
                currentTime -= 24 # set currentime if it is above 24 hour clock
              #if there is not enough time left, stay in the same place
            if timeCount > 23:
                continue
            #next activity  
            row = data.loc[data['start'] == currentP]
           # currentP = row["start"].value
            chooseList = []
            for place in ["home", "work", "hospital", "market", "school"]:
                if float(row[place]) > 0:
                    chooseList.append((place,float(row[place])))
            selectNumber = 0
            nextProb = prob
            while (nextP == currentP) and (nextProb == prob):
                #n1 = math.floor(random.random()* len(chooseList))
                #selectNumber = random.choice([0, n1])
                place = choosePlace(selectNumber, chooseList)
                nextP = place[0]
                nextProb = place[1]
                selectNumber += 1
            prob = nextProb
            if nextP == currentP:
                currentP = nextP
                continue
                
            if nextP == "home":
                nextTask = "go home"
            elif nextP == "work":
                nextTask = "go to work"
            elif nextP == "hospital":
                nextTask = "go to Hospital"
            elif nextP == "school":
                nextTask = "go to school"
            else:
                nextTask = "go to market"
            minProb = random.random()* prob
            maxProb = random.random()* prob
            if maxProb < minProb:
                maxProb = minProb
            duration = round (1 + random.random())
            min_start_time = currentTime
            max_start_time = round( random.choice([currentTime,currentTime + random.random()]))
            #update currentTime and timeCount, adjust duration
            if (timeCount + duration) >= 24:
                duration = 24 - timeCount
            currentTime = currentTime + duration
            timeCount = timeCount + duration
            df.append([ iD, nextTask, min_start_time, max_start_time, duration, duration, p, minProb, maxProb])

            if currentTime >= 24:
                currentTime -= 24 # set currentime if it is above 24 hour clock              

    database = pd.DataFrame(df, columns=[headers])         

    return database

# %%
import random
from random import choice
import math
import time
def generateHealthcareTasks(n):

    df = []
    employed, unemployed, student, healthcare = loadHumanNeed()
    
    headers = [ "ID","task", "min_start_time" , "max_start_time" , "min_duration" , "max_duration" , "profession", "min_prob" , "max_prob" ]
    data = healthcare
    for i in range(0, n):
        p = "Healthcare"
        iD = "he" + str(i)
 
        firstRow = data.iloc[0]
        currentP = firstRow["start"]
   
        nextP = firstRow["start"]
        duration = 0
        currentTime = randrange(12)

        timeCount = 0
        row = firstRow

        prob = 0.5
        nextTask = ""
        while timeCount < 24:
            min_start_time = currentTime
            max_start_time = round (random.choice([currentTime,currentTime + 2*random.random()]))
            currentP = nextP
            if currentP == "home":
                taskName = "stay home"
                minProb = prob
                maxProb = random.random()
                if maxProb < minProb:
                    maxProb = minProb
                if prob > 0.4:
                    duration = 4 + round(4 * random.random())
                else:
                    duration = 1 + round(2 * random.random())
                maxduration = random.choice([duration, duration+1])
            
            elif currentP == "work":
                taskName = "work"
                minProb = prob
                maxProb = random.random()
                if maxProb < minProb:
                    maxProb = minProb
                if prob > 0.4:
                    duration = 4 + round(4 * random.random())
                else:
                    duration = 1 + round( random.random())
                maxduration = random.choice([duration, duration+1])
              
            elif currentP == "hospital":
                taskName = "treat patients"
                minProb = prob
                maxProb = random.random()
                if maxProb < minProb:
                    maxProb = minProb
                if prob > 0.4:
                    duration = 6 + round(2 * random.random())
                else:
                    duration = 2 + round(2 * random.random())
                maxduration = random.choice([duration, duration+1])
               
            elif currentP == "market":
                minProb = prob
                maxProb = random.random()
                if maxProb < minProb:
                    maxProb = minProb
                if prob > 0.4:
                    duration = 2 + round(2 * random.random())
                    taskName = random.choice([ "meeting","attending event","relaxation","dating"])
                else:
                    duration = 1 + round(random.random())
                    taskName = random.choice(["shopping", "eating"])
                maxduration = random.choice([duration, duration+1])
            
            elif currentP == "school":
                minProb = prob
                maxProb = random.random()
                if maxProb < minProb:
                    maxProb = minProb
                if prob > 0.4:
                    taskName = random.choice(["class time", "researching" ])
                    duration = 3 + round(5 * random.random())
                else:
                    taskName = random.choice(["groupwork", "homework" ])
                    duration = 2 + round(2 * random.random())
                maxduration = random.choice([duration, duration+1])
            

            #update currentTime and timeCount, adjust duration
            if (timeCount + duration) >= 22:
                duration = 24 - timeCount
            currentTime = currentTime + duration
            timeCount = timeCount + duration
      
            df.append([iD, taskName, min_start_time, max_start_time, duration, maxduration, p, minProb, maxProb])
            if currentTime >= 24:
                currentTime -= 24 # set currentime if it is above 24 hour clock
              #if there is not enough time left, stay in the same place
            if timeCount > 23:
                continue
            #next activity  
            row = data.loc[data['start'] == currentP]
           # currentP = row["start"].value
            chooseList = []
            for place in ["home", "work", "hospital", "market", "school"]:
                if float(row[place]) > 0:
                    chooseList.append((place,float(row[place])))
            selectNumber = 0
            nextProb = prob
            while (nextP == currentP) and (nextProb == prob):
                #n1 = math.floor(random.random()* len(chooseList))
                #selectNumber = random.choice([0, n1])
                place = choosePlace(selectNumber, chooseList)
                nextP = place[0]
                nextProb = place[1]
                selectNumber += 1
            prob = nextProb
            if nextP == currentP:
                currentP = nextP
                continue
                
            if nextP == "home":
                nextTask = "go home"
            elif nextP == "work":
                nextTask = "go to work"
            elif nextP == "hospital":
                nextTask = "go to Hospital"
            elif nextP == "school":
                nextTask = "go to school"
            else:
                nextTask = "go to market"
            minProb = random.random()* prob
            maxProb = random.random()* prob
            if maxProb < minProb:
                maxProb = minProb
            duration = round (1 + random.random())
            min_start_time = currentTime
            max_start_time = round( random.choice([currentTime,currentTime + random.random()]))
            #update currentTime and timeCount, adjust duration
            if (timeCount + duration) >= 24:
                duration = 24 - timeCount
            currentTime = currentTime + duration
            timeCount = timeCount + duration
            df.append([ iD, nextTask, min_start_time, max_start_time, duration, duration, p, minProb, maxProb])

            if currentTime >= 24:
                currentTime -= 24 # set currentime if it is above 24 hour clock              

    database = pd.DataFrame(df, columns=[headers])         

    return database

# %%
student_df = generateStudentTasks(10000)
healthcare_df = generateHealthcareTasks(1000)
unemployed_df = generateUnemployedTasks(100)
employed_df = generateEmployedTasks(50000)

# %%
employed_df
# Out:
#              ID        task min_start_time max_start_time min_duration  \
# 0           em0   stay home              2              3            8
# 1           em0  go to work             10             10            2
# 2           em0        work             12             13            5
# 3           em0     go home             17             17            1
# 4           em0   stay home             18             19            5
# ...         ...         ...            ...            ...          ...
# 308657  em49999   stay home              2              4            7
# 308658  em49999  go to work              9              9            1
# 308659  em49999        work             10             10            7
# 308660  em49999     go home             17             18            1
# 308661  em49999   stay home             18             20            8
#
#        max_duration profession  min_prob  max_prob
# 0                 9   Employed  0.500000  0.500000
# 1                 2   Employed  0.040727  0.044631
# 2                 6   Employed  0.900000  0.900000
# 3                 1   Employed  0.183673  0.282485
# 4                 6   Employed  0.500000  0.786412
# ...             ...        ...       ...       ...
# 308657            8   Employed  0.500000  0.500000
# 308658            1   Employed  0.189813  0.269720
# 308659            8   Employed  0.900000  0.900000
# 308660            1   Employed  0.209091  0.304209
# 308661            9   Employed  0.500000  0.603467
#
# [308662 rows x 9 columns]

# %%
student_df
# Out:
#            ID             task min_start_time max_start_time min_duration  \
# 0         st0        stay home             10             11            4
# 1         st0        stay home             14             16            6
# 2         st0     go to market             20             21            2
# 3         st0  attending event             22             23            4
# 4         st0          go home              2              2            2
# ...       ...              ...            ...            ...          ...
# 62895  st9999        stay home             17             17            7
# 62896  st9999     go to market              0              0            2
# 62897  st9999          meeting              2              4            2
# 62898  st9999          go home              4              4            1
# 62899  st9999        stay home              5              5            6
#
#       max_duration profession  min_prob  max_prob
# 0                5    Student  0.500000  0.500000
# 1                6    Student  0.900000  0.900000
# 2                2    Student  0.393773  0.393773
# 3                4    Student  0.700000  0.700000
# 4                2    Student  0.844757  0.870742
# ...            ...        ...       ...       ...
# 62895            8    Student  0.900000  0.900000
# 62896            2    Student  0.113718  0.420293
# 62897            2    Student  0.700000  0.735381
# 62898            1    Student  0.071084  0.273805
# 62899            5    Student  0.900000  0.900000
#
# [62900 rows x 9 columns]

# %%
healthcare_df
# Out:
#          ID            task min_start_time max_start_time min_duration  \
# 0       he0       stay home              9             10            5
# 1       he0  go to Hospital             14             15            1
# 2       he0  treat patients             15             17            8
# 3       he0         go home             23             23            1
# 4       he0       stay home              0              0            4
# ...     ...             ...            ...            ...          ...
# 5805  he999       stay home              7              7            8
# 5806  he999  go to Hospital             15             15            2
# 5807  he999  treat patients             17             17            7
# 5808  he999         go home              0              0            1
# 5809  he999       stay home              1              2            6
#
#      max_duration  profession  min_prob  max_prob
# 0               5  Healthcare  0.500000  0.500000
# 1               1  Healthcare  0.443759  0.443759
# 2               8  Healthcare  0.900000  0.900000
# 3               1  Healthcare  0.399589  0.399589
# 4               5  Healthcare  0.500000  0.500000
# ...           ...         ...       ...       ...
# 5805            9  Healthcare  0.500000  0.664872
# 5806            2  Healthcare  0.071481  0.261529
# 5807            7  Healthcare  0.900000  0.900000
# 5808            1  Healthcare  0.303059  0.303059
# 5809            7  Healthcare  0.500000  0.500000
#
# [5810 rows x 9 columns]

# %%
unemployed_df
# Out:
#        ID             task min_start_time max_start_time min_duration  \
# 0     un0        stay home             10             11            6
# 1     un0        stay home             16             17            6
# 2     un0     go to market             22             22            1
# 3     un0          meeting             23             23            2
# 4     un0          go home              1              1            1
# ..    ...              ...            ...            ...          ...
# 608  un99        stay home             15             15            7
# 609  un99     go to market             22             22            2
# 610  un99  attending event              0              0            3
# 611  un99          go home              3              4            1
# 612  un99        stay home              4              6            5
#
#     max_duration  profession  min_prob  max_prob
# 0              6  Unemployed  0.500000  0.500000
# 1              6  Unemployed  0.900000  0.900000
# 2              1  Unemployed  0.121660  0.327752
# 3              3  Unemployed  0.700000  0.702582
# 4              1  Unemployed  0.542480  0.542480
# ..           ...         ...       ...       ...
# 608            8  Unemployed  0.900000  0.900000
# 609            2  Unemployed  0.155809  0.504138
# 610            3  Unemployed  0.700000  0.700000
# 611            1  Unemployed  0.171353  0.654660
# 612            5  Unemployed  0.800000  0.800000
#
# [613 rows x 9 columns]
